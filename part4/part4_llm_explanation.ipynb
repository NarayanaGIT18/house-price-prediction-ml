# %%
# !pip install requests python-dotenv jsonschema

# %%
import os
import json
import re
import requests
import joblib

from jsonschema import validate, ValidationError
import pandas as pd
import numpy as np

# %%
def predict_house_price(input_data):
    prediction = model.predict(input_data)
    return prediction[0]

print("Prediction function created")

# %%
def generate_explanation(predicted_price):
    response = {
        "Predicted Price": predicted_price,
        "Summary": "The model estimated the house price based on the provided property features.",
        "Recommendation": "Consider location, quality, and size factors when evaluating the prediction."
    }
    return response


result = generate_explanation(250000)

result
